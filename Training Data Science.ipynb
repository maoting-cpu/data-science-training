# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Maoting Shan**
#
# 100% human

# %% [markdown]
# *I am interested in data science because i want to become a data analyst.*

# %% [markdown]
# ### Converting integer to binary in python

# %%
    def convertToBinary(integer):
        result=""
        while (integer > 0):
            digit = integer % 2
            result+=str(digit)
            integer = int (integer/2)
            resut = result[::-1]
        return result
    
    print(convertToBinary(123))
# Out:
# 1101111

# %% [markdown]
# Today is:
# 1. Monday
# 2. Tuesday
# 3. Wednsday
# 4. Thursday
# 5. Friday
# 6. Saturday
# 7. Sonday
#
#
# Hours spend on learning Data Science:
#
#
# | capiter      | hour      | Notice     |
# |--------------|-----------|------------|
# | Data Science | 6         | completed  |
# | Tools        | 10        | ongoing    |
#
#
#
#
#
# Check out here [IBM Watson](https://www.ibm.com/de-de/cloud/watson-studio) for more fun.
